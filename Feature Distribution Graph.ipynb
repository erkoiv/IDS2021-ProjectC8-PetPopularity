# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
tree = [10, 25, 50, 45, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')
ax.bar(labels, tree, width, yerr=women_std, bottom= (np.array(men_means)+np.array(women_means)), 
       label='Tree')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
#Lodaing the data
import pandas as pd
df = pd.read_csv("./FeatureDistribution.csv")
df
# Out:
#         Features    80-100      50-80      30-50       0-30
# 0        Overall  5.831316  15.546812  39.497579  39.124294
# 1   SubjectFocus  4.744526  16.788321  37.226277  41.240876
# 2           Eyes  5.654218  15.330373  40.258553  38.756856
# 3           Face  5.781250  15.602679  39.977679  38.638393
# 4           Near  5.983607  15.421546  39.285714  39.309133
# 5         Action  6.060606  14.141414  42.424242  37.373737
# 6      Accessory  6.250000  16.369048  39.583333  37.797619
# 7          Group  5.694228  16.926677  42.043682  35.335413
# 8        Collage  5.487805  15.243902  40.853659  38.414634
# 9          Human  5.461165  16.201456  41.383495  36.953883
# 10     Occlusion  4.926686  15.542522  43.401760  36.129032
# 11          Info  5.601318  13.838550  43.163097  37.397035
# 12          Blur  5.157593  14.183381  37.822350  42.836676

# %%
labels = df['Features']
val_80_100 = df['80-100']
val_50_80 = df['50-80']
val_30_50 = df['30-50']
val_0_30 = df['0-30']

width = 0.60 

fig, ax = plt.subplots(figsize = (15,10))

ax.bar(labels, val_80_100, width, label='80-100')
ax.bar(labels, val_50_80, width, bottom =val_80_100,  label='50-80' )
ax.bar(labels, val_30_50, width,bottom = (np.array(val_80_100)+np.array(val_50_80)),
       label='30-50')
ax.bar(labels, val_0_30, width,bottom = (np.array(val_80_100)+np.array(val_50_80) + np.array(val_30_50)),
       label='0-30')

ax.set_ylabel('PawPularity')
ax.set_title('PawPularity Distribution By Features')
ax.legend()

plt.show()
fig.savefig('featureDistribution.png')
plt.close(fig)
